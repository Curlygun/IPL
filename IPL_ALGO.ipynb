# %%
import pandas as pd
df = pd.read_csv('IPL_Final.csv')

# %%
df.tail()
# Out:
#       match_id  inning  batting_team  bowling_team  batsman_runs  extra_runs  \
# 1481     11413       2            14             1           165           5
# 1482     11414       1            14             9           147           8
# 1483     11414       2             9            14           151          11
# 1484     11415       1             3             9           149           3
# 1485     11415       2             9             3           148           9
#
#       wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  Wickets  \
# 1481          4         1            0            0             0        7
# 1482          2         0            5            1             0        9
# 1483          6         0            5            0             0        4
# 1484          3         0            0            0             0        8
# 1485          4         5            0            0             0        7
#
# ...

# %%
df.shape[0]
# Out:
# 1486

# %%
Y=df[['winner']]
df.shape[0]
X_trian=df.loc[0:df.shape[0]-2, df.columns != 'winner']
X_test=df.loc[df.shape[0]-2:df.shape[0], df.columns != 'winner']
Y_trian=df.loc[0:df.shape[0]-2, df.columns == 'winner']
Y_test=df.loc[df.shape[0]-2:df.shape[0], df.columns == 'winner']

# %%
# from sklearn.model_selection import\
# train_test_split
# # Split Training and Testing Data
# X_train,X_test,Y_train,Y_test = \
# train_test_split(X,Y,test_size = 0.25,\
#                  random_state=1)

from sklearn.naive_bayes import GaussianNB
# Initialize a Naive Bayes Model
model = GaussianNB()
# P(A/B) = P(B/A) * P(A) / P(B)
X_train.shape
Y_train.shape
# Fit the model on given Data
model.fit(X_train,Y_train)

# model.class_prior_
# model.class_count_

# Predict using Naive Bayes Model
Y_predict = model.predict(X_test)

# from sklearn.metrics import\
# confusion_matrix,accuracy_score
# # Calculate Confusion Matrix
# cf_mat=confusion_matrix(Y_test,Y_predict)

# # Calculate Accuracy
# acc = accuracy_score(Y_test,Y_predict)

# #Print Results
# print("Confusion Matrix \n",cf_mat)
# print("Accuracy : ",acc)
# Out:
# /Users/phalgunvyas/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(Y_predict)
# Out:
# [14 14]

# %%
print(Y_test)
# Out:
#       winner
# 1484       3
# 1485       3

# %%
#decision tree classifier

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train,Y_train)
Y_predict=model.predict(X_test)
print(Y_predict)
# Out:
# [3 3]

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, Y_train)

#Predict the response for test dataset
Y_pred = clf.predict(X_test)

print(Y_pred)
# Out:
# /Users/phalgunvyas/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [14  1]

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier

# Import Support Vector Classifier
from sklearn.svm import SVC
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
svc=SVC(probability=True, kernel='linear')

# Create adaboost classifer object
model =AdaBoostClassifier(n_estimators=10, base_estimator=svc,learning_rate=1)
model.fit(X_train,Y_train)
Y_predict=model.predict(X_test)
print(Y_predict)
# Out:
# /Users/phalgunvyas/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [3 3]

# %%
num_trees = 30
seed=7
kfold = KFold(n_splits=10, random_state=seed)
model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
model =AdaBoostClassifier(n_estimators=10, base_estimator=svc,learning_rate=1)
model.fit(X_train,Y_train)
Y_predict=model.predict(X_test)
print(Y_predict)
# Out:
# /Users/phalgunvyas/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [3 3]
